# %% [markdown]
# # Phytoplankton Campbeltown
#
# ![](phytoplankton.png)
#
# ![](phytoplankton_no_trig.png)
#
# ![](phytoplankton_trig.png)

# %% [markdown]
# ![](e_coli_campbeltown_loch.png)

# %% [markdown]
# ![](e_coli_aith_voe_sletta.png)

# %%
ls
# Out:
# e_coli_aith_voe_sletta.png
# e_coli_ardencaple.png
# e_coli_ardencaple_.png
# e_coli_arisaig.png
# e_coli_arran_pirnmill.png
# e_coli_ayr_bay.png
# e_coli_baltasound_mussels.png
# e_coli_basta_voe_cove.png
# e_coli_basta_voe_outer.png
# e_coli_brindister_voe.png
# e_coli_broad_bay_aiginish.png
# e_coli_busta_voe_lee_north.png
# e_coli_busta_voe_lee_south.png
# e_coli_campbeltown_loch.png
# e_coli_carradale_bay.png
# e_coli_castle_stalker.png
# e_coli_catfirth.png
# e_coli_catfirth_mussels_1.png
# e_coli_catfirth_mussels_2.png
# e_coli_cidhe_eolaigearraidh.png
# e_coli_clift_sound:_booth.png
# e_coli_clift_sound:_stream_sound.png
# e_coli_clift_sound:_whal_wick_.png
# e_coli_clift_sound_houss.png
# e_coli_coll_razors.png
# e_coli_colla_firth.png
# e_coli_colonsay.png
# e_coli_colonsay_east_of_the_strand.png
# e_coli_croy_bay.png
# e_coli_dales_voe:_muckle_ayre.png
# e_coli_dales_voe:_scarvar_ayre.png
# e_coli_dales_voe_-_fora_ness.png
# e_coli_dunstaffnage_cockles.png
# ...

# %% [markdown]
# ![](e_coli_carradale_bay.png)
